# %% [markdown]
# # KNN
# Simple Fruits dataset example

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
fruits=pd.read_table('fruitdata.txt')

# %%
fruits
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
fruits.groupby('fruit_name').mean()
# Out:
#             fruit_label        mass     width    height  color_score
# fruit_name
# apple               1.0  165.052632  7.457895  7.342105     0.783684
# lemon               4.0  150.000000  6.512500  8.856250     0.718125
# mandarin            2.0   81.200000  5.940000  4.380000     0.796000
# orange              3.0  193.789474  7.557895  7.936842     0.771053

# %%
plt.title('Fruits Count')
sns.countplot(fruits['fruit_name']);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.title('Comparison between the different fruits and their masses')
sns.scatterplot(fruits['fruit_name'], fruits['mass'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.title('Comparison between the different fruits and their width')
sns.scatterplot(fruits['fruit_name'], fruits['width'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.title('Comparison between the different fruits and their height')
sns.scatterplot(fruits['fruit_name'], fruits['height'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.title('Comparison between the different fruits and their color_score')
sns.scatterplot(fruits['fruit_name'], fruits['color_score'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,8))
plt.title('Comparison between the different fruits heigt and width')
sns.scatterplot(fruits['height'], fruits['width'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,8))
plt.title('Comparison between the different fruits heigt and width')
sns.scatterplot(fruits['mass'], fruits['width'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,8))
plt.title('Comparison between the different fruits heigt and width')
sns.scatterplot(fruits['mass'], fruits['height'], hue = fruits['fruit_name'], s= 100);
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X=fruits[['mass','width','height']]
y=fruits['fruit_label']
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
X_train
# Out:
#     mass  width  height
# 42   154    7.2     7.2
# 48   174    7.3    10.1
# 7     76    5.8     4.0
# 14   152    7.6     7.3
# 32   164    7.2     7.0
# 49   132    5.8     8.7
# 29   160    7.0     7.4
# 37   154    7.3     7.3
# 56   116    5.9     8.1
# 18   162    7.5     7.1
# 55   116    6.3     7.7
# 27   204    7.5     9.2
# 15   156    7.7     7.1
# 5     80    5.8     4.3
# 31   210    7.8     8.0
# 16   156    7.6     7.5
# 50   130    6.0     8.2
# 20   160    7.5     7.5
# 51   116    6.0     7.5
# 8    178    7.1     7.8
# 13   164    7.3     7.7
# 25   356    9.2     9.2
# 17   168    7.5     7.6
# 58   118    6.1     8.1
# 57   152    6.5     8.5
# 52   118    5.9     8.0
# 38   158    7.2     7.8
# 1    180    8.0     6.8
# 12   154    7.0     7.1
# 45   186    7.2     9.2
# 24   342    9.0     9.4
# 6     80    5.9     4.3
# 23   170    7.6     7.9
# 36   160    7.1     7.6
# 21   156    7.4     7.4
# 19   162    7.4     7.2
# 9    172    7.4     7.0
# ...

# %%
y_test
# Out:
# 26    3
# 35    3
# 43    4
# 28    3
# 11    1
# 2     1
# 34    3
# 46    4
# 40    3
# 22    1
# 4     2
# 10    1
# 30    3
# 41    3
# 33    3
# Name: fruit_label, dtype: int64

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test,y_test)
# Out:
# 0.5333333333333333

# %%
myprediction=knn.predict([['100','6.3','8']])
myprediction[0]
# Out:
# /home/rishabh/myfiles/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# 4

# %%
if (myprediction[0]==1):
    print("apple")
elif (myprediction[0]==2):
    print("mandarin")
elif (myprediction[0]==3):
    print("orange")
elif (myprediction[0]==4):
    print("lemon")
else:
    print("Incorrecty Labelled")
# Out:
# lemon
